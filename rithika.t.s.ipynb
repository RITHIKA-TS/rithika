# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("/content/winequalityN.csv")

# %%
x=df.sulphates
y=df.pH

# %%
df.head(100)
plt.plot(x)

# %%
df.plot.box()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %%
df.plot(kind="scatter",x="sulphates",y="pH")

# %%
plt.polar(x)

# %%
plt.fill_between(x,y)

# %%
df.plot.area()

# %%
plt.pie(df["free sulfur dioxide"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7fa4fb9b9610>,
# ...
# ...
#   Text(0.7629394088537338, 0.7924162153930947, ''),
#   Text(0.7620602651577808, 0.7932617173844034, ''),
#   Text(0.760991473912893, 0.7942870870358417, ''),
#   Text(0.7597323062641108, 0.7954915604949027, ''),
#   Text(0.7588371397755524, 0.7963455250688979, ''),
#   Text(0.7577768300712269, 0.7973545483705496, ''),
#   Text(0.7562091593770622, 0.7988414781884058, ''),
#   Text(0.754638570995668, 0.8003253258304502, ''),
#   Text(0.7534841090199798, 0.8014123142642415, ''),
#   Text(0.7528745311469252, 0.8019850000781172, ''),
#   Text(0.7523789285993596, 0.8024499659166794, ''),
#   Text(0.7517431206894322, 0.8030456279042393, ''),
#   Text(0.7511323014169689, 0.8036169894720047, ''),
#   Text(0.750737583146765, 0.8039857469202761, ''),
#   Text(0.7499348560690877, 0.804734559747894, ''),
#   Text(0.7485697831141055, 0.8060045159975849, ''),
#   Text(0.7472792831476656, 0.8072011353921098, ''),
# ...

# %%
df.plot.hist()
